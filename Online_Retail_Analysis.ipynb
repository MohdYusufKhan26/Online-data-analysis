# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-02-19 06:43:41--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [    <=>             ]  22.62M  29.4MB/s    in 0.8s
#
# 2025-02-19 06:43:42 (29.4 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1 = pd.read_excel('Online Retail.xlsx', dtype={'InvoiceNo' : 'string', 'StockCode' : 'string', 'Description' : 'string', 'country' : 'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1), string(3)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Data Cleaning : Handle Missing Values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df1[df1.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
df1[df1.StockCode=="22139"].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %%
most_freq = df1[["StockCode", "Description"]].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787    35833P                               check      1
# 4788     21410     COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412            VINTAGE GOLD TINSEL REEL      1
# 4790     21414             SCALLOP SHELL SOAP DISH      1
# 4791     35972                               check      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode == "85123A"].head(1)
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq = most_freq.groupby("StockCode").head(1)
most_freq
# Out:
#      StockCode                          Description  count
# 0       85123A   WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423             REGENCY CAKESTAND 3 TIER   2200
# 2       85099B              JUMBO BAG RED RETROSPOT   2159
# 3        47566                        PARTY BUNTING   1727
# 4        20725              LUNCH BAG RED RETROSPOT   1638
# ...        ...                                  ...    ...
# 4784     35832  WOOLLY HAT SOCK GLOVE ADVENT STRING      1
# 4785    35833G         4 GOLD FLOCK CHRISTMAS BALLS      1
# 4788     21410      COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412             VINTAGE GOLD TINSEL REEL      1
# 4790     21414              SCALLOP SHELL SOAP DISH      1
#
# [3958 rows x 3 columns]

# %%
most_freq.columns = ["StockCode", "freq_Description", "count"]

df2 = df1.merge(most_freq, on="StockCode", how="left")
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                 WHITE METAL LANTERN   328.0
# 2      CREAM CUPID HEARTS COAT HANGER   293.0

# %%
df2['Description'] = df2["freq_Description"]
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                 WHITE METAL LANTERN   328.0
# 2      CREAM CUPID HEARTS COAT HANGER   293.0

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# freq_Description       112
# count                  112
# dtype: int64

# %%
df2.dropna(subset=["Description"], inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          134968
# Country                  0
# freq_Description         0
# count                    0
# dtype: int64

# %%
df2.drop(columns=["freq_Description", "count"], inplace=True)
df2.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541797.000000                         541797  541797.000000
# mean        9.555919  2011-07-04 14:06:48.671255296       4.612067
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:36:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 11:41:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.103428                            NaN      96.769831
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df2[df2.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df3 = df2[(df2.Quantity>0) & (df2.UnitPrice>0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID
# count  397884.000000
# mean    15294.423453
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.141560

# %%
df3.Quantity.quantile(0.99999)
# Out:
# 3164.325840001926

# %%
df3[df3.Quantity>1500].head(5)
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 4850     536809     84950      ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945     536830     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 25920    538420     17096   ASSORTED LAQUERED INCENSE HOLDERS      1728
# 32671    539101     22693  GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 52709    540815    85123A  WHITE HANGING HEART T-LIGHT HOLDER      1930
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 4850  2010-12-02 16:48:00       0.55     15299.0  United Kingdom
# 4945  2010-12-02 17:38:00       0.18     16754.0  United Kingdom
# 25920 2010-12-12 12:03:00       0.17     12875.0  United Kingdom
# 32671 2010-12-16 10:35:00       0.94     16029.0  United Kingdom
# 52709 2011-01-11 12:55:00       2.55     15749.0  United Kingdom

# %% [markdown]
# ### Features Engineering : Creates New Column

# %%
df4 = df3.copy()
df4['TotalPrice'] = df4.Quantity * df4.UnitPrice
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00

# %%
df4['Month'] = df4["InvoiceDate"].dt.month
df4.sample(3)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 420633    572899     22865             HAND WARMER OWL DESIGN         1
# 274389    560908     23293  SET OF 12 FAIRY CAKE BAKING CASES        16
# 170330    551286     22699   ROSES REGENCY TEACUP AND SAUCER          6
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 420633 2011-10-26 14:50:00       2.10     13435.0  United Kingdom        2.10
# 274389 2011-07-21 17:56:00       0.83     15827.0  United Kingdom       13.28
# 170330 2011-04-27 14:16:00       2.95     13767.0  United Kingdom       17.70
#
#         Month
# 420633     10
# 274389      7
# 170330      4

# %% [markdown]
# ### Visualization : EDA

# %% [markdown]
# ##### 1.   Plot Monthly Sales

# %%
Monthly_Sales = df4.groupby("Month")["TotalPrice"].sum()
Monthly_Sales.plot(kind="line", title="Monthly Sales", marker="o")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid()
plt.show()

# %%
# prompt: plot a line chart using month and totalprice sum also provide data label

import pandas as pd
from matplotlib import pyplot as plt

# Assuming df4 is already created as in the provided code
# If not, recreate it here using the code from the previous response

Monthly_Sales = df4.groupby("Month")["TotalPrice"].sum()

plt.figure(figsize=(10, 6))  # Adjust figure size for better readability
plt.plot(Monthly_Sales.index, Monthly_Sales.values, marker='o', linestyle='-')
plt.title('Monthly Sales', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Add data labels
for x, y in zip(Monthly_Sales.index, Monthly_Sales.values):
    plt.text(x, y, f'{y:.0f}', ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ###### Total Sales starting rising up in August Having a peek in November. This is likely due to the holiday season at the end of the year.

# %% [markdown]
# ##### 2. Top 5 Countries

# %%
# prompt: plot horizontal bar chart for top 5 countries by total sales make it colourfull

# Assuming df4 is already created as in the provided code
# If not, recreate it here using the code from the previous response

top_countries = df4.groupby('Country')['TotalPrice'].sum().nlargest(5)

plt.figure(figsize=(10, 6))
bars = plt.barh(top_countries.index, top_countries.values, color=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightseagreen'])

# Add data labels
for bar, value in zip(bars, top_countries.values):
    plt.text(value, bar.get_y() + bar.get_height()/2, f'{value:,.0f}', va='center', ha='left')

plt.title('Top 5 Countries by Total Sales', fontsize=16)
plt.xlabel('Total Sales', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ## Insights
#
# 1. UK has the highest sales (around 9 million)
# 2. Netherlands, EIRE, Germany and France are the next 4 countries each having a sales of more than 2 million
#
#
# ###### Since these countries cover the major sales revenues, we need to pay special attention to customers in these countries and make sure our product quality and service are the best. Also to break dependancy of sales from a single country we can focus on expanding sales in other countries as well##

# %%
# prompt: plot same chart but this time use percentage contribution. show % on the bar.

import pandas as pd
from matplotlib import pyplot as plt

# Assuming df4 is already created as in the provided code
# If not, recreate it here using the code from the previous response

country_wise_sales = df4.groupby('Country')['TotalPrice'].sum()
total_sales = country_wise_sales.sum()


top_5_countries = country_wise_sales.sort_values(ascending=False).head(5)
percentages = (top_5_countries / total_sales) * 100

plt.figure(figsize=(10, 6))
bars = plt.barh(percentages.index, percentages.values, color=['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightseagreen'])


# Add percentage labels on the bars
for bar, percentage in zip(bars, percentages.values):
    plt.text(percentage, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center', ha='left')


plt.title('Top 5 Countries by Total Sales (Percentage Contribution)', fontsize=16)
plt.xlabel('Percentage Contribution to Total Sales', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)


plt.show()

# %% [markdown]
# #### 3. Top 5 Products Based on total sales

# %%
product_wise_sales = df4.groupby('StockCode')['TotalPrice'].sum()

top_5_products = product_wise_sales.sort_values(ascending=False).head(5)
top_5_products.plot(kind='barh', title='Top 5 Products by Total Sales', color='skyblue')
plt.xlabel('Stock Code')
plt.ylabel('Total Sales')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.gca().invert_yaxis()
plt.show()

# %%
product_wise_sales.sort_values(ascending=False).head()
# Out:
# StockCode
# DOT       206248.77
# 22423     174484.74
# 23843     168469.60
# 85123A    104518.80
# 47566      99504.33
# Name: TotalPrice, dtype: float64

# %%
product_wise_sales.sum()
# Out:
# 10666684.544

# %%
df4[df4.StockCode == "DOT"].head(5)
# Out:
#      InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 1814    536544       DOT  DOTCOM POSTAGE         1 2010-12-01 14:32:00
# 3041    536592       DOT  DOTCOM POSTAGE         1 2010-12-01 17:06:00
# 5450    536862       DOT  DOTCOM POSTAGE         1 2010-12-03 11:13:00
# 5545    536864       DOT  DOTCOM POSTAGE         1 2010-12-03 11:27:00
# 5685    536865       DOT  DOTCOM POSTAGE         1 2010-12-03 11:28:00
#
#       UnitPrice  CustomerID         Country  TotalPrice  Month
# 1814     569.77         NaN  United Kingdom      569.77     12
# 3041     607.49         NaN  United Kingdom      607.49     12
# 5450     254.43         NaN  United Kingdom      254.43     12
# 5545     121.06         NaN  United Kingdom      121.06     12
# 5685     498.47         NaN  United Kingdom      498.47     12

# %%
for stock_code in top_5_products.index:
  description = df4[df4.StockCode == stock_code].Description.iloc[0]
  print(f"{stock_code} ==> {description}")
# Out:
# DOT ==> DOTCOM POSTAGE
# 22423 ==> REGENCY CAKESTAND 3 TIER
# 23843 ==> PAPER CRAFT , LITTLE BIRDIE
# 85123A ==> WHITE HANGING HEART T-LIGHT HOLDER
# 47566 ==> PARTY BUNTING

# %%
# prompt: plot the same chart as above for products sales but use percentage this time. show % on the bar

import pandas as pd
import matplotlib.pyplot as plt

# Assuming df4 is already created as in the provided code
# If not, recreate it here using the code from the previous response

product_wise_sales = df4.groupby('StockCode')['TotalPrice'].sum()
total_sales = product_wise_sales.sum()

top_5_products = product_wise_sales.sort_values(ascending=False).head(5)
percentages = (top_5_products / total_sales) * 100

plt.figure(figsize=(10, 6))
bars = plt.barh(top_5_products.index, percentages.values, color='skyblue')

# Add percentage labels on the bars
for bar, percentage in zip(bars, percentages.values):
    plt.text(percentage, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center', ha='left')

plt.title('Top 5 Products by Total Sales (Percentage Contribution)', fontsize=16)
plt.xlabel('Percentage Contribution to Total Sales', fontsize=12)
plt.ylabel('StockCode', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### 4. RFM Analysis (Recency, Frequency, Monetary)

# %%
current_dt = df4['InvoiceDate'].max() + pd.Timedelta(days=1)
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
current_date = df4['InvoiceDate'].max() + pd.Timedelta(days=1)
rfm = df4.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (current_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPrice': 'sum'
})
rfm.columns = ['Recency', 'Frequency', 'Monetary']
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40

# %%
df4[df4.CustomerID == 12346]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom     77183.6
#
#        Month
# 61619      1

# %%
df4[df4.CustomerID == 12347]["TotalPrice"].sum()
# Out:
# 4310.000000000001

# %%
rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  4338.000000  4338.000000    4338.000000
# mean     92.536422    91.720609    2054.266460
# std     100.014169   228.785094    8989.230441
# min       1.000000     1.000000       3.750000
# 25%      18.000000    17.000000     307.415000
# 50%      51.000000    41.000000     674.485000
# 75%     142.000000   100.000000    1661.740000
# max     374.000000  7847.000000  280206.020000

# %%
# Segment Customers based on RFM
rfm['R_Segment'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])
rfm['F_Segment'] = pd.qcut(rfm['Frequency'], 4, labels=[1, 2, 3, 4])
rfm['M_Segment'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])
rfm['RFM_Score'] = rfm[['R_Segment', 'F_Segment', 'M_Segment']].sum(axis=1)

# %%
rfm
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 12346.0         326          1  77183.60         1         1         4
# 12347.0           2        182   4310.00         4         4         4
# 12348.0          75         31   1797.24         2         2         4
# 12349.0          19         73   1757.55         3         3         4
# 12350.0         310         17    334.40         1         1         2
# ...             ...        ...       ...       ...       ...       ...
# 18280.0         278         10    180.60         1         1         1
# 18281.0         181          7     80.82         1         1         1
# 18282.0           8         12    178.05         4         1         1
# 18283.0           4        756   2094.88         4         4         4
# 18287.0          43         70   1837.28         3         3         4
#
#             RFM_Score
# CustomerID
# 12346.0             6
# 12347.0            12
# ...

# %%
# Customers with highest RFM Scores
rfm.sort_values('RFM_Score', ascending=False)
# Out:
#             Recency  Frequency  Monetary R_Segment F_Segment M_Segment  \
# CustomerID
# 18198.0           4        159   5425.56         4         4         4
# 18210.0           2        134   2621.38         4         4         4
# 18225.0           3        271   5509.12         4         4         4
# 18283.0           4        756   2094.88         4         4         4
# 16983.0          13        148   1931.25         4         4         4
# ...             ...        ...       ...       ...       ...       ...
# 12402.0         323         11    225.60         1         1         1
# 18185.0         249         17    304.25         1         1         1
# 18190.0         192         15    284.46         1         1         1
# 18191.0         262          7    207.80         1         1         1
# 18193.0         165         16    243.76         1         1         1
#
#             RFM_Score
# CustomerID
# 18198.0            12
# 18210.0            12
# ...

# %% [markdown]
# ##### 5. Customer Churn Analysis

# %%
df4.head(4)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    Month
# 0     12
# 1     12
# 2     12
# 3     12

# %%
# create a basket matrix for association rule mining
customer_last_purschase = df4.groupby("CustomerID")["InvoiceDate"].max()
customer_last_purschase.head(5)
# Out:
# CustomerID
# 12346.0   2011-01-18 10:01:00
# 12347.0   2011-12-07 15:52:00
# 12348.0   2011-09-25 13:13:00
# 12349.0   2011-11-21 09:51:00
# 12350.0   2011-02-02 16:01:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
type(customer_last_purschase)
# Out:
# pandas.core.series.Series

# %%
current_date
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
customer_last_purschase = (current_date - customer_last_purschase).dt.days
customer_last_purschase
# Out:
# CustomerID
# 12346.0    326
# 12347.0      2
# 12348.0     75
# 12349.0     19
# 12350.0    310
#           ...
# 18280.0    278
# 18281.0    181
# 18282.0      8
# 18283.0      4
# 18287.0     43
# Name: InvoiceDate, Length: 4338, dtype: int64

# %%
# Define churn threshold (e.g., 90 days without purchase)
churn_threshold = 90
churned_customers = customer_last_purschase[customer_last_purschase > churn_threshold]
churned_customers.head(5)
# Out:
# CustomerID
# 12346.0    326
# 12350.0    310
# 12353.0    204
# 12354.0    232
# 12355.0    214
# Name: InvoiceDate, dtype: int64

# %%
print("Number of Churned Customers:", len(churned_customers))
plt.figure(figsize=(10, 6))
plt.hist(customer_last_purschase, bins=50, color='red', alpha=0.7)
plt.axvline(churn_threshold, color='black', linestyle='dashed', linewidth=2)
plt.title('Customer Churn Distribution')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Number of Customers')
plt.show()
# Out:
# Number of Churned Customers: 1449
